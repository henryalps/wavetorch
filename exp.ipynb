# %%
# install all requirements.
# !conda install --yes --file requirements.txt
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/homebrew/Caskroom/miniforge/base/envs/py37
#
#   added / updated specs:
#     - librosa[version='>=0.6.3']
#     - matplotlib[version='>=3.0.3']
#     - numpy[version='>=1.16.0']
#     - pandas[version='>=0.25.0']
#     - pytorch[version='>=1.2']
#     - scikit-image[version='>=0.15.0']
#     - scikit-learn[version='>=0.21.0']
#     - seaborn[version='>=0.9.0']
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     appdirs-1.4.4              |     pyh9f0ad1d_0          13 KB  conda-forge
#     audioread-2.1.9            |   py39h2804cbe_0          33 KB  conda-forge
#     blosc-1.21.0               |       h9f76cd9_0         765 KB  conda-forge
#     brotli-1.0.9               |       h3422bc3_5          18 KB  conda-forge
# ...

# %%
# !conda install yaml
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.

# %%
# !python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# creating wavetorch.egg-info
# writing wavetorch.egg-info/PKG-INFO
# writing dependency_links to wavetorch.egg-info/dependency_links.txt
# writing top-level names to wavetorch.egg-info/top_level.txt
# writing manifest file 'wavetorch.egg-info/SOURCES.txt'
# reading manifest file 'wavetorch.egg-info/SOURCES.txt'
# adding license file 'LICENSE.md'
# writing manifest file 'wavetorch.egg-info/SOURCES.txt'
# installing library code to build/bdist.macosx-11.0-arm64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/wavetorch
# copying wavetorch/plot.py -> build/lib/wavetorch
# copying wavetorch/cell.py -> build/lib/wavetorch
# copying wavetorch/geom.py -> build/lib/wavetorch
# copying wavetorch/io.py -> build/lib/wavetorch
# copying wavetorch/__init__.py -> build/lib/wavetorch
# copying wavetorch/utils.py -> build/lib/wavetorch
# copying wavetorch/probe.py -> build/lib/wavetorch
# ...

# %%
# !cp -r wavetorch study

# %%
# !python ./study/vowel_train.py ./study/example.yml
# Out:
# Configuration: ./study/example.yml
# Dataset: 12 vowel samples
# Epoch  0/ 5 --- Elapsed Time:  0.08 min | Training Loss:  nan | Testing Loss:  nan | Training Accuracy:  0.3333 | Testing Accuracy:  0.5000
# Epoch  1/ 5 --- Elapsed Time:  0.16 min | Training Loss:  nan | Testing Loss:  nan | Training Accuracy:  0.5000 | Testing Accuracy:  0.5000
# Epoch  2/ 5 --- Elapsed Time:  0.13 min | Training Loss:  nan | Testing Loss:  nan | Training Accuracy:  0.3333 | Testing Accuracy:  0.5000
# Epoch  3/ 5 --- Elapsed Time:  0.16 min | Training Loss:  nan | Testing Loss:  nan | Training Accuracy:  0.3333 | Testing Accuracy:  0.5000
# Epoch  4/ 5 --- Elapsed Time:  0.18 min | Training Loss:  nan | Testing Loss:  nan | Training Accuracy:  0.3333 | Testing Accuracy:  0.5000
# Epoch  5/ 5 --- Elapsed Time:  0.18 min | Training Loss:  nan | Testing Loss:  nan | Training Accuracy:  0.3333 | Testing Accuracy:  0.5000
# Total Time: 0.90 min
#
# Saving model to ./study/ex_20210916200918.pt
